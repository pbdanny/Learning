# %% [markdown]
# # Shelter Animal Outcomes

# %% [markdown]
# https://www.kaggle.com/c/shelter-animal-outcomes

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
animals = pd.read_csv('data/train.csv')

# %%
animals.head()
# Out:
#   AnimalID     Name             DateTime      OutcomeType OutcomeSubtype  \
# 0  A671945  Hambone  2014-02-12 18:22:00  Return_to_owner            NaN
# 1  A656520    Emily  2013-10-13 12:44:00       Euthanasia      Suffering
# 2  A686464   Pearce  2015-01-31 12:28:00         Adoption         Foster
# 3  A683430      NaN  2014-07-11 19:09:00         Transfer        Partner
# 4  A667013      NaN  2013-11-15 12:52:00         Transfer        Partner
#
#   AnimalType SexuponOutcome AgeuponOutcome                        Breed  \
# 0        Dog  Neutered Male         1 year        Shetland Sheepdog Mix
# 1        Cat  Spayed Female         1 year       Domestic Shorthair Mix
# 2        Dog  Neutered Male        2 years                 Pit Bull Mix
# 3        Cat    Intact Male        3 weeks       Domestic Shorthair Mix
# 4        Dog  Neutered Male        2 years  Lhasa Apso/Miniature Poodle
#
#          Color
# 0  Brown/White
# 1  Cream Tabby
# 2   Blue/White
# 3   Blue Cream
# 4          Tan

# %%
animals.AgeuponOutcome.value_counts().plot(kind='bar', figsize=(10, 6))

# %%
sns.countplot(data=animals, x=animals.AgeuponOutcome)

# %%
g = sns.countplot(data=animals, x=animals.AgeuponOutcome)
g.set_xticklabels(g.get_xticklabels(), rotation=90)  # rotate xlabel vertical
# Out:
# [<matplotlib.text.Text at 0x114c1ac50>,
#  <matplotlib.text.Text at 0x114792be0>,
#  <matplotlib.text.Text at 0x116573d68>,
#  <matplotlib.text.Text at 0x116577898>,
#  <matplotlib.text.Text at 0x11657a3c8>,
#  <matplotlib.text.Text at 0x11657aeb8>,
#  <matplotlib.text.Text at 0x11657e9e8>,
#  <matplotlib.text.Text at 0x116582518>,
#  <matplotlib.text.Text at 0x116585048>,
#  <matplotlib.text.Text at 0x116585b38>,
#  <matplotlib.text.Text at 0x116589668>,
#  <matplotlib.text.Text at 0x11658d198>,
#  <matplotlib.text.Text at 0x11658dc88>,
#  <matplotlib.text.Text at 0x1165907b8>,
#  <matplotlib.text.Text at 0x1165932e8>,
#  <matplotlib.text.Text at 0x116593dd8>,
#  <matplotlib.text.Text at 0x116598908>,
#  <matplotlib.text.Text at 0x11659b438>,
#  <matplotlib.text.Text at 0x11659bf28>,
#  <matplotlib.text.Text at 0x11659fa58>,
#  <matplotlib.text.Text at 0x1165a3588>,
#  <matplotlib.text.Text at 0x1165a70b8>,
#  <matplotlib.text.Text at 0x1165a7ba8>,
#  <matplotlib.text.Text at 0x1165aa6d8>,
#  <matplotlib.text.Text at 0x1165ae208>,
#  <matplotlib.text.Text at 0x1165aecf8>,
#  <matplotlib.text.Text at 0x1165b3828>,
#  <matplotlib.text.Text at 0x1165b5358>,
#  <matplotlib.text.Text at 0x1165b5e48>,
#  <matplotlib.text.Text at 0x1165bb978>,
#  <matplotlib.text.Text at 0x1165bd4a8>,
#  <matplotlib.text.Text at 0x1165bdf98>,
#  <matplotlib.text.Text at 0x1165c1ac8>,
#  <matplotlib.text.Text at 0x1165c65f8>,
#  <matplotlib.text.Text at 0x1165c8128>,
#  <matplotlib.text.Text at 0x1165c8c18>,
#  <matplotlib.text.Text at 0x1165cc748>,
#  <matplotlib.text.Text at 0x1165d0278>,
#  <matplotlib.text.Text at 0x1165d0d68>,
#  <matplotlib.text.Text at 0x1165d4898>,
#  <matplotlib.text.Text at 0x1165d93c8>,
#  <matplotlib.text.Text at 0x1165d9eb8>,
#  <matplotlib.text.Text at 0x1165dd9e8>,
#  <matplotlib.text.Text at 0x1165e0518>]

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 6))  # Expand plot size
g = sns.countplot(data=animals, x=animals.AgeuponOutcome, ax=ax)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [<matplotlib.text.Text at 0x116573860>,
#  <matplotlib.text.Text at 0x118b26240>,
#  <matplotlib.text.Text at 0x118bda7b8>,
#  <matplotlib.text.Text at 0x118bdf2e8>,
#  <matplotlib.text.Text at 0x118bdfdd8>,
#  <matplotlib.text.Text at 0x118be2908>,
#  <matplotlib.text.Text at 0x118be5438>,
#  <matplotlib.text.Text at 0x118be5f28>,
#  <matplotlib.text.Text at 0x118beaa58>,
#  <matplotlib.text.Text at 0x118bec588>,
#  <matplotlib.text.Text at 0x118bf00b8>,
#  <matplotlib.text.Text at 0x118bf0ba8>,
#  <matplotlib.text.Text at 0x118bf36d8>,
#  <matplotlib.text.Text at 0x118bf7208>,
#  <matplotlib.text.Text at 0x118bf7cf8>,
#  <matplotlib.text.Text at 0x118d40828>,
#  <matplotlib.text.Text at 0x118d44358>,
#  <matplotlib.text.Text at 0x118d44e48>,
#  <matplotlib.text.Text at 0x118d48978>,
#  <matplotlib.text.Text at 0x118d4b4a8>,
#  <matplotlib.text.Text at 0x118d4bf98>,
#  <matplotlib.text.Text at 0x118d50ac8>,
#  <matplotlib.text.Text at 0x118d545f8>,
#  <matplotlib.text.Text at 0x118d57128>,
#  <matplotlib.text.Text at 0x118d57c18>,
#  <matplotlib.text.Text at 0x118d5d748>,
#  <matplotlib.text.Text at 0x118d60278>,
#  <matplotlib.text.Text at 0x118d60d68>,
#  <matplotlib.text.Text at 0x118d62898>,
#  <matplotlib.text.Text at 0x118d673c8>,
#  <matplotlib.text.Text at 0x118d67eb8>,
#  <matplotlib.text.Text at 0x118d6c9e8>,
#  <matplotlib.text.Text at 0x118d6e518>,
#  <matplotlib.text.Text at 0x118d73048>,
#  <matplotlib.text.Text at 0x118d73b38>,
#  <matplotlib.text.Text at 0x118d75668>,
#  <matplotlib.text.Text at 0x118d7a198>,
#  <matplotlib.text.Text at 0x118d7ac88>,
#  <matplotlib.text.Text at 0x118d7e7b8>,
#  <matplotlib.text.Text at 0x118d812e8>,
#  <matplotlib.text.Text at 0x118d81dd8>,
#  <matplotlib.text.Text at 0x118d87908>,
#  <matplotlib.text.Text at 0x118d8a438>,
#  <matplotlib.text.Text at 0x118d8af28>]

# %%
def get_age_in_days(age_upon_outcome):
    if str(age_upon_outcome) == 'nan':
        return 0
    time_value, unit = age_upon_outcome.split(' ')
    if unit == 'year' or unit == 'years':
        return int(time_value) * 365
    if unit in ['month', 'months']:
        return int(time_value) * 30
    if unit in ['week', 'weeks']:
        return int(time_value) * 7
    if unit in ['day', 'days']:
        return int(time_value)

# %%
def get_age_in_year(age_upon_outcome):
    if str(age_upon_outcome) == 'nan':
        return 0
    time_value, unit = age_upon_outcome.split(' ')
    if unit == 'year' or unit == 'years':
        return float(time_value)
    if unit in ['month', 'months']:
        return float(time_value) / 12
    if unit in ['week', 'weeks']:
        return float(time_value) / 52
    if unit in ['day', 'days']:
        return float(time_value) / 365

# %%
animals['AgeInDays'] = animals.AgeuponOutcome.map(get_age_in_days)
animals['AgeInYears'] = animals.AgeuponOutcome.map(get_age_in_year)

# %%
animals.head()
# Out:
#   AnimalID     Name             DateTime      OutcomeType OutcomeSubtype  \
# 0  A671945  Hambone  2014-02-12 18:22:00  Return_to_owner            NaN
# 1  A656520    Emily  2013-10-13 12:44:00       Euthanasia      Suffering
# 2  A686464   Pearce  2015-01-31 12:28:00         Adoption         Foster
# 3  A683430      NaN  2014-07-11 19:09:00         Transfer        Partner
# 4  A667013      NaN  2013-11-15 12:52:00         Transfer        Partner
#
#   AnimalType SexuponOutcome AgeuponOutcome                        Breed  \
# 0        Dog  Neutered Male         1 year        Shetland Sheepdog Mix
# 1        Cat  Spayed Female         1 year       Domestic Shorthair Mix
# 2        Dog  Neutered Male        2 years                 Pit Bull Mix
# 3        Cat    Intact Male        3 weeks       Domestic Shorthair Mix
# 4        Dog  Neutered Male        2 years  Lhasa Apso/Miniature Poodle
#
#          Color  AgeInDays  AgeInYears
# 0  Brown/White        365    1.000000
# 1  Cream Tabby        365    1.000000
# 2   Blue/White        730    2.000000
# 3   Blue Cream         21    0.057692
# 4          Tan        730    2.000000

# %%
animals.boxplot(column=['AgeInYears'], by='OutcomeType', figsize=(10, 6))

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 6))
sns.boxplot(data=animals, x='OutcomeType', y='AgeInYears', ax=ax)

# %%
pd.cut(animals.AgeInDays, list(range(0, 7000, 100))).head(5)
animals.groupby(pd.cut(animals.AgeInDays, list(range(0, 7000, 350)))).mean()
avg_data_by_age = animals.groupby(pd.cut(animals.AgeInDays, list(range(0, 7000, 350)))).count()
avg_data_by_age.AgeInDays.plot(kind='bar')

# %%
sns.distplot(animals.AgeInDays, bins=20, kde=False)

# %% [markdown]
# ดู distribution ของสัตว์แต่ละชนิด

# %%
animals.AnimalType.value_counts().plot(kind='bar')

# %%
sns.countplot(data=animals, x=animals.AnimalType)

# %% [markdown]
# ดู distribution ของ outcome type

# %%
animals['OutcomeType'].value_counts().plot(kind='bar')

# %%
sns.countplot(data=animals, x=animals.OutcomeType)

# %% [markdown]
# เทียบ distribution ของสัตว์แต่ละชนิดโดยแยกตาม outcome type

# %%
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
animals[['AnimalType', 'OutcomeType']].groupby(['OutcomeType', 'AnimalType']).size().unstack().plot(kind='bar', ax=ax1, rot=0)
animals[['AnimalType', 'OutcomeType']].groupby(['AnimalType', 'OutcomeType']).size().unstack().plot(kind='bar', ax=ax2, rot=0)

# %%
f, ax = plt.subplots(1, 2, figsize=(16, 4))
animals[['AnimalType', 'OutcomeType']].groupby(['OutcomeType', 'AnimalType']).size().unstack().plot(kind='bar', ax=ax[0], rot=0)
animals[['AnimalType', 'OutcomeType']].groupby(['AnimalType', 'OutcomeType']).size().unstack().plot(kind='bar', ax=ax[1], rot=0)

# %%
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
sns.countplot(data=animals, x='OutcomeType', hue='AnimalType', ax=ax1)
sns.countplot(data=animals, x='AnimalType',hue='OutcomeType', ax=ax2)

# %% [markdown]
# ดู distribution ของเพศ

# %%
animals['SexuponOutcome'].value_counts().plot(kind='bar')

# %%
sns.countplot(data=animals, x=animals.SexuponOutcome)

# %%
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
animals[['SexuponOutcome', 'OutcomeType']].groupby(['OutcomeType', 'SexuponOutcome']).size().unstack().plot(kind='bar', ax=ax1)
animals[['SexuponOutcome', 'OutcomeType']].groupby(['SexuponOutcome', 'OutcomeType']).size().unstack().plot(kind='bar', ax=ax2)

# %%
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
sns.countplot(data=animals, x='OutcomeType', hue='SexuponOutcome', ax=ax1)
sns.countplot(data=animals, x='SexuponOutcome',hue='OutcomeType', ax=ax2)

# %%
def get_sex(x):
    x = str(x)
    if 'Male' in x: return 'male'
    if 'Female' in x: return 'female'
    return 'unknown'

# %%
animals['Sex'] = animals.SexuponOutcome.apply(get_sex)  # map used with series , apply use with dataframe

# %%
animals.Sex.value_counts().plot(kind='bar')

# %%
sns.countplot(x=animals.Sex)

# %%
def get_neutered(x):
    x = str(x)
    if 'Spayed' in x: return 'neutered'
    if 'Neutered' in x: return 'neutered'
    if 'Intact' in x: return 'intact'
    return 'unknown'

# %%
animals['Neutered'] = animals.SexuponOutcome.apply(get_neutered)

# %%
animals.Neutered.value_counts().plot(kind='bar')

# %%
sns.countplot(x=animals.Neutered)

# %%
_, (ax1, ax2) = plt.subplots(2, 2, figsize=(16, 8), )
animals[['Sex', 'OutcomeType']].groupby(['OutcomeType', 'Sex']).size().unstack().plot(kind='bar', ax=ax1[0], rot=0)
animals[['Sex', 'OutcomeType']].groupby(['Sex', 'OutcomeType']).size().unstack().plot(kind='bar', ax=ax1[1], rot=0)
animals[['Neutered', 'OutcomeType']].groupby(['OutcomeType', 'Neutered']).size().unstack().plot(kind='bar', ax=ax2[0], rot=0)
animals[['Neutered', 'OutcomeType']].groupby(['Neutered', 'OutcomeType']).size().unstack().plot(kind='bar', ax=ax2[1], rot=0)

# %%
_, (ax1, ax2) = plt.subplots(2, 2, figsize=(16, 8))
sns.countplot(data=animals, x='OutcomeType', hue='Sex', ax=ax1[0])
sns.countplot(data=animals, x='Sex', hue='OutcomeType', ax=ax1[1])
sns.countplot(data=animals, x='OutcomeType', hue='Neutered', ax=ax2[0])
sns.countplot(data=animals, x='Neutered', hue='OutcomeType', ax=ax2[1])

# %% [markdown]
# ช่วงเวลาก็อาจจะมีส่วนในการตัดสินใจ?

# %%
animals['Converted-DateTime'] = pd.to_datetime(animals["DateTime"]).dt.date

# %%
animals.head()
# Out:
#   AnimalID     Name             DateTime      OutcomeType OutcomeSubtype  \
# 0  A671945  Hambone  2014-02-12 18:22:00  Return_to_owner            NaN
# 1  A656520    Emily  2013-10-13 12:44:00       Euthanasia      Suffering
# 2  A686464   Pearce  2015-01-31 12:28:00         Adoption         Foster
# 3  A683430      NaN  2014-07-11 19:09:00         Transfer        Partner
# 4  A667013      NaN  2013-11-15 12:52:00         Transfer        Partner
#
#   AnimalType SexuponOutcome AgeuponOutcome                        Breed  \
# 0        Dog  Neutered Male         1 year        Shetland Sheepdog Mix
# 1        Cat  Spayed Female         1 year       Domestic Shorthair Mix
# 2        Dog  Neutered Male        2 years                 Pit Bull Mix
# 3        Cat    Intact Male        3 weeks       Domestic Shorthair Mix
# 4        Dog  Neutered Male        2 years  Lhasa Apso/Miniature Poodle
#
#          Color  AgeInDays  AgeInYears     Sex  Neutered Converted-DateTime
# 0  Brown/White        365    1.000000    male  neutered         2014-02-12
# 1  Cream Tabby        365    1.000000  female  neutered         2013-10-13
# 2   Blue/White        730    2.000000    male  neutered         2015-01-31
# 3   Blue Cream         21    0.057692    male    intact         2014-07-11
# 4          Tan        730    2.000000    male  neutered         2013-11-15

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26729 entries, 0 to 26728
# Data columns (total 15 columns):
# AnimalID              26729 non-null object
# Name                  19038 non-null object
# DateTime              26729 non-null object
# OutcomeType           26729 non-null object
# OutcomeSubtype        13117 non-null object
# AnimalType            26729 non-null object
# SexuponOutcome        26728 non-null object
# AgeuponOutcome        26711 non-null object
# Breed                 26729 non-null object
# Color                 26729 non-null object
# AgeInDays             26729 non-null int64
# AgeInYears            26729 non-null float64
# Sex                   26729 non-null object
# Neutered              26729 non-null object
# Converted-DateTime    26729 non-null object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 3.1+ MB

# %%
monthGroup = animals["Converted-DateTime"].groupby(animals["OutcomeType"])

# %%
f, ax = plt.subplots(5, 1, figsize=(16, 17))

animals[animals.OutcomeType == 'Adoption'].groupby('Converted-DateTime')['Converted-DateTime'].count().plot(ax=ax[0])
animals[animals.OutcomeType == 'Died'].groupby('Converted-DateTime')['Converted-DateTime'].count().plot(ax=ax[1])
animals[animals.OutcomeType == 'Euthanasia'].groupby('Converted-DateTime')['Converted-DateTime'].count().plot(ax=ax[2])
animals[animals.OutcomeType == 'Return_to_owner'].groupby('Converted-DateTime')['Converted-DateTime'].count().plot(ax=ax[3])
animals[animals.OutcomeType == 'Transfer'].groupby('Converted-DateTime')['Converted-DateTime'].count().plot(ax=ax[4])

# %%
f, ax = plt.subplots(5, 1, figsize=(16, 17))

month_group = animals['Converted-DateTime'].groupby(animals['OutcomeType'])
for i, g in enumerate(month_group):
    g[1].groupby(animals['Converted-DateTime']).count().plot(ax=ax[i])

# %%
animals.head(3)
# Out:
#   AnimalID     Name             DateTime      OutcomeType OutcomeSubtype  \
# 0  A671945  Hambone  2014-02-12 18:22:00  Return_to_owner            NaN
# 1  A656520    Emily  2013-10-13 12:44:00       Euthanasia      Suffering
# 2  A686464   Pearce  2015-01-31 12:28:00         Adoption         Foster
#
#   AnimalType SexuponOutcome AgeuponOutcome                   Breed  \
# 0        Dog  Neutered Male         1 year   Shetland Sheepdog Mix
# 1        Cat  Spayed Female         1 year  Domestic Shorthair Mix
# 2        Dog  Neutered Male        2 years            Pit Bull Mix
#
#          Color  AgeInDays  AgeInYears     Sex  Neutered Converted-DateTime
# 0  Brown/White        365         1.0    male  neutered         2014-02-12
# 1  Cream Tabby        365         1.0  female  neutered         2013-10-13
# 2   Blue/White        730         2.0    male  neutered         2015-01-31

# %%
X = animals.drop(['AnimalID', 'Name', 'DateTime', 'AgeInDays','OutcomeType', 'OutcomeSubtype', 'SexuponOutcome', 'AgeuponOutcome', 'Converted-DateTime'], axis=1)
y = animals['OutcomeType']

# %%
X.head()
# Out:
#   AnimalType                        Breed        Color  AgeInYears     Sex  \
# 0        Dog        Shetland Sheepdog Mix  Brown/White    1.000000    male
# 1        Cat       Domestic Shorthair Mix  Cream Tabby    1.000000  female
# 2        Dog                 Pit Bull Mix   Blue/White    2.000000    male
# 3        Cat       Domestic Shorthair Mix   Blue Cream    0.057692    male
# 4        Dog  Lhasa Apso/Miniature Poodle          Tan    2.000000    male
#
#    Neutered
# 0  neutered
# 1  neutered
# 2  neutered
# 3    intact
# 4  neutered

# %%
y.head()
# Out:
# 0    Return_to_owner
# 1         Euthanasia
# 2           Adoption
# 3           Transfer
# 4           Transfer
# Name: OutcomeType, dtype: object

# %%
X.isnull().sum()
# Out:
# AnimalType    0
# Breed         0
# Color         0
# AgeInYears    0
# Sex           0
# Neutered      0
# dtype: int64

# %%
X.count()
# Out:
# AnimalType    26729
# Breed         26729
# Color         26729
# AgeInYears    26729
# Sex           26729
# Neutered      26729
# dtype: int64

# %%
y.count()
# Out:
# 26729

# %%
from sklearn import preprocessing
# Preprocessing data process
# sklearn cannot process string data, encode all string -> numeric

animals_test = pd.read_csv("data/test.csv")

le_animal_type = preprocessing.LabelEncoder()  # instantiate
le_animal_type.fit(X.AnimalType)  # prefit data, find all possible label
X.AnimalType = le_animal_type.transform(X.AnimalType)  # Encode label

le_sex = preprocessing.LabelEncoder()
le_sex.fit(X.Sex)
X.Sex = le_sex.transform(X.Sex)

le_neutered = preprocessing.LabelEncoder()
le_neutered.fit(X.Neutered)
X.Neutered = le_neutered.transform(X.Neutered)

le_breed = preprocessing.LabelEncoder()
le_breed.fit(X.Breed.append(animals_test.Breed))
X.Breed = le_breed.transform(X.Breed)

le_color = preprocessing.LabelEncoder()
le_color.fit(X.Color.append(animals_test.Color))
X.Color = le_color.transform(X.Color)

le_out = preprocessing.LabelEncoder()
le_out.fit(y)
y = le_out.transform(y)

# %%
X.head()
# Out:
#    AnimalType  Breed  Color  AgeInYears  Sex  Neutered
# 0           1   1482    146    1.000000    1         1
# 1           0    775    184    1.000000    0         1
# 2           1   1293     97    2.000000    1         1
# 3           0    775     47    0.057692    1         0
# 4           1   1101    311    2.000000    1         1

# %%
y
# Out:
# array([3, 2, 0, ..., 0, 4, 4])

# %%
le_out.inverse_transform(y)  # Show label
# Out:
# array(['Return_to_owner', 'Euthanasia', 'Adoption', ..., 'Adoption',
#        'Transfer', 'Transfer'], dtype=object)

# %%
from sklearn import grid_search, neighbors

k_range = list(range(1, 31))
param_grid = dict(n_neighbors=k_range)

knn = neighbors.KNeighborsClassifier()
grid = grid_search.GridSearchCV(knn, param_grid, cv=3, scoring='accuracy')
grid.fit(X, y)

grid_mean_scores = [result.mean_validation_score for result in grid.grid_scores_]

# %%
plt.plot(k_range, grid_mean_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Accuracy')

# %%
print(grid.best_score_)
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# 0.552957461933
# {'n_neighbors': 9}
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=9, p=2,
#            weights='uniform')

# %%
from sklearn import grid_search, ensemble
# Random forest <- combined decision tree

n_range = [100, 150]
param_grid = dict(n_estimators=n_range)

rf = ensemble.RandomForestClassifier()
grid = grid_search.GridSearchCV(rf, param_grid, cv=3, scoring='accuracy')
grid.fit(X, y)

grid_mean_scores = [result.mean_validation_score for result in grid.grid_scores_]

# %%
plt.plot(n_range, grid_mean_scores)
plt.xlabel('Value of estimators for Random Forest')
plt.ylabel('Cross-Validated Accuracy')

# %%
print(grid.best_score_)
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# 0.59224063751
# {'n_estimators': 150}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=150, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# ## ลองใช้โมเดลกับชุดข้อมูลทดสอบ

# %%
animals_test = pd.read_csv("data/test.csv")
animals_test.head()
# Out:
#    ID      Name             DateTime AnimalType SexuponOutcome AgeuponOutcome  \
# 0   1    Summer  2015-10-12 12:15:00        Dog  Intact Female      10 months
# 1   2  Cheyenne  2014-07-26 17:59:00        Dog  Spayed Female        2 years
# 2   3       Gus  2016-01-13 12:20:00        Cat  Neutered Male         1 year
# 3   4     Pongo  2013-12-28 18:12:00        Dog    Intact Male       4 months
# 4   5   Skooter  2015-09-24 17:59:00        Dog  Neutered Male        2 years
#
#                             Breed        Color
# 0          Labrador Retriever Mix    Red/White
# 1  German Shepherd/Siberian Husky    Black/Tan
# 2          Domestic Shorthair Mix  Brown Tabby
# 3               Collie Smooth Mix     Tricolor
# 4            Miniature Poodle Mix        White

# %%
# Encode all test data like train data
animals_test['AgeInYears'] = animals_test.AgeuponOutcome.map(get_age_in_year)
animals_test['Sex'] = animals_test.SexuponOutcome.apply(get_sex)
animals_test['Neutered'] = animals_test.SexuponOutcome.apply(get_neutered)

# %%
animals_test.head(3)
# Out:
#    ID      Name             DateTime AnimalType SexuponOutcome AgeuponOutcome  \
# 0   1    Summer  2015-10-12 12:15:00        Dog  Intact Female      10 months
# 1   2  Cheyenne  2014-07-26 17:59:00        Dog  Spayed Female        2 years
# 2   3       Gus  2016-01-13 12:20:00        Cat  Neutered Male         1 year
#
#                             Breed        Color  AgeInYears     Sex  Neutered
# 0          Labrador Retriever Mix    Red/White    0.833333  female    intact
# 1  German Shepherd/Siberian Husky    Black/Tan    2.000000  female  neutered
# 2          Domestic Shorthair Mix  Brown Tabby    1.000000    male  neutered

# %%
X_test = animals_test.drop(['ID', 'Name', 'DateTime', 'SexuponOutcome', 'AgeuponOutcome'], axis=1)

# %%
X_test.head(3)
# Out:
#   AnimalType                           Breed        Color  AgeInYears     Sex  \
# 0        Dog          Labrador Retriever Mix    Red/White    0.833333  female
# 1        Dog  German Shepherd/Siberian Husky    Black/Tan    2.000000  female
# 2        Cat          Domestic Shorthair Mix  Brown Tabby    1.000000    male
#
#    Neutered
# 0    intact
# 1  neutered
# 2  neutered

# %%
X_test.AnimalType = le_animal_type.transform(X_test.AnimalType)
X_test.Sex = le_sex.transform(X_test.Sex)
X_test.Neutered = le_neutered.transform(X_test.Neutered)
X_test.Breed = le_breed.transform(X_test.Breed)
X_test.Color = le_color.transform(X_test.Color)

# %%
X_test.head()
# Out:
#    AnimalType  Breed  Color  AgeInYears  Sex  Neutered
# 0           1   1023    283    0.833333    0         0
# 1           1    875     40    2.000000    0         1
# 2           0    775    117    1.000000    1         1
# 3           1    658    346    0.333333    1         0
# 4           1   1165    359    2.000000    1         1

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators=150)
rf.fit(X, y)
y_pred_class = rf.predict(X_test)

# %%
y_pred_class
# Out:
# array([4, 3, 4, ..., 4, 0, 2])

# %%
y_pred_class = le_out.inverse_transform(y_pred_class)

# %% [markdown]
# สร้างไฟล์ submission เตรียมส่ง Kaggle

# %%
import csv

def create_submission(y_pred_class):
    f = open('submission.csv', 'w')
    filewrite = csv.writer(f)
    filewrite.writerow(["ID", "Adoption", "Died", "Euthanasia", "Return_to_owner", "Transfer"])
    for index, each in enumerate(y_pred_class):
        result = [str(index + 1)]
        if each == 'Adoption':
            result.append(1)
        else:
            result.append(0)
        if each == 'Died':
            result.append(1)
        else:
            result.append(0)
        if each == 'Euthanasia':
            result.append(1)
        else:
            result.append(0)
        if each == 'Return_to_owner':
            result.append(1)
        else:
            result.append(0)
        if each == 'Transfer':
            result.append(1)
        else:
            result.append(0)
            
        filewrite.writerow(result)
        
    f.close()

# %%
create_submission(y_pred_class)
